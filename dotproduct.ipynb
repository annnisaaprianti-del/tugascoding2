# %%
import numpy as np

# %%
#buat vector x dan y dengan ukuran 1x3 menggunakan numpy
x = np.array([18, 1, 8])
x
# Out:
# array([18,  1,  8])

# %%
#buat vector x dan y dengan ukuran 1x3 menggunakan numpy
y = np.array([8, 1, 81])
y
# Out:
# array([ 8,  1, 81])

# %%
import torch

# %%
#buat vector x_pt dan y_pt dengan ukuran 1x3 menggunakan pytorch
x_pt = torch.tensor([18, 1, 8])
x_pt
# Out:
# tensor([18,  1,  8])

# %%
#buat vector x_pt dan y_pt dengan ukuran 1x3 menggunakan pytorch
y_pt = torch.tensor([8, 1, 81])
y_pt
# Out:
# tensor([ 8,  1, 81])

# %%
import tensorflow as tf

# %%
#buat vector x_tf dan y_tf dengan ukuran 1x3 menggunakan tensorflow
x_tf = tf.Variable([18, 1, 8])
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([18,  1,  8], dtype=int32)>

# %%
#buat vector x_tf dan y_tf dengan ukuran 1x3 menggunakan tensorflow
y_tf = tf.Variable([8, 1, 81])
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([ 8,  1, 81], dtype=int32)>

# %%
#hitung perkalian dot product antara vector x dan vector y
np.dot(x, y)
# Out:
# np.int64(793)

# %%
#hitung perkalian dot product antara vector x_pt dan vector y_pt
torch.dot(x_pt, y_pt)
# Out:
# tensor(793)

# %%
#hitung perkalian dot product antara vector x_tf dan vector y_tf
tf.reduce_sum(tf.multiply(x_tf, y_tf))
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=793>
